# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/train.csv')
X2 = pd.read_csv('../data/test.csv')
df
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          NaN     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    NaN     No
# 12009  SID0x5af7          NaN    Yes     No    NaN     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# ...

# %%
from math import floor
df['Subject Age'].describe()
df['Subject Age'] = df['Subject Age'].fillna(floor(df['Subject Age'].mean()))

X2['Subject Age'] = X2['Subject Age'].fillna(floor(X2['Subject Age'].mean()))
df
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          6.0     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    NaN     No
# 12009  SID0x5af7          6.0    Yes     No    NaN     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# ...

# %%
df.drop('Diagnostic Testing', axis = 1, inplace=True)
X2.drop('Diagnostic Testing', axis = 1, inplace=True)
df
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          6.0     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    NaN     No
# 12009  SID0x5af7          6.0    Yes     No    NaN     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# ...

# %%
X2.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Carrier Testing', 'Enzyme Test', 'Insulin Test', 'Thyroid Test',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP'],
#       dtype='object')

# %%
print(df.columns)
X2.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Carrier Testing', 'Enzyme Test', 'Insulin Test', 'Thyroid Test',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP',
#        'Metabolic Syndrome Type'],
#       dtype='object')
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Carrier Testing', 'Enzyme Test', 'Insulin Test', 'Thyroid Test',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
# ...

# %%
df.drop(df.iloc[:, 9:13], axis = 1, inplace=True)
X2.drop(X2.iloc[:, 9:13], axis = 1, inplace=True)
print(df.columns)
X2.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP',
#        'Metabolic Syndrome Type'],
#       dtype='object')
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
# ...

# %%
columns = ['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
       'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate', 'Gender', 'Gastrin Defect', 'Neural Anomaly',
       'Presence of severe allergies', 'Premature Delivery',
       'Assistance needed in fertility', 'Previous maternal pregnancy record',
       'Maternal Abortion count', 'Per mcL quantity of white blood cells',
       'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP',
       'Metabolic Syndrome Type']

# %%
for i in columns:
    print(i, end=' ')
    print(df[i].unique())

colms = ['Subject Id', 'Gene A', 'Gene B', 'Gene C', 'Gene D','Breathing Rate', 'Pulse rate', 'Gender', 'Gastrin Defect', 'Neural Anomaly',
       'Presence of severe allergies', 'Premature Delivery',
       'Assistance needed in fertility', 'Previous maternal pregnancy record', 'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP']

floatcol = ['Subject Age', 'Per mcL quantity of blood cells', 'Maternal Abortion count','Per mcL quantity of white blood cells','A high triglyceride level', 'Reduced HDL', 'High BP']
# Out:
# Subject Id ['SID0x62bb' 'SID0x78c' 'SID0x88f4' ... 'SID0x5af7' 'SID0x52d1'
#  'SID0x5642']
# Subject Age [ 1.  6.  7.  5. 13. 14.  9. 11.  0.  8. 10.  4.  3. 12.  2.]
# Gene A ['No' 'Yes']
# Gene B ['No' 'Yes' nan]
# Gene C ['No' 'Yes' nan]
# Gene D ['No' 'Yes']
# Per mcL quantity of blood cells [4.7170454  4.88807663 5.11261073 ... 5.11438106 4.98815419 4.67174522]
# Breathing Rate ['Tachypnea' 'Normal (30-60)' nan]
# Pulse rate ['Normal' 'Tachycardia' nan]
# Gender [nan 'Ambiguous' 'Male' 'Female']
# Gastrin Defect ['No' 'Yes' nan]
# Neural Anomaly [nan 'No' 'Yes']
# Presence of severe allergies ['Not applicable' 'Yes' 'No' '-' nan]
# Premature Delivery ['Yes' '-' 'Not applicable' 'No' nan]
# Assistance needed in fertility ['No' 'Yes' nan]
# Previous maternal pregnancy record ['Yes' nan 'No']
# Maternal Abortion count [ 3. nan  0.  4.  2.  1.]
# Per mcL quantity of white blood cells [11.85735415  5.03079289  7.24813432 ...  4.65370501  9.54191694
#   9.27797511]
# ...

# %%
df.head()
# Out:
#   Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0  SID0x62bb          1.0     No     No     No     No
# 1   SID0x78c          6.0     No    Yes    Yes     No
# 2  SID0x88f4          7.0     No     No     No    Yes
# 3  SID0x919e          7.0     No     No    Yes    Yes
# 4  SID0x8534          5.0    Yes     No    Yes    Yes
#
#    Per mcL quantity of blood cells  Breathing Rate   Pulse rate     Gender  \
# 0                         4.717045       Tachypnea       Normal        NaN
# 1                         4.888077       Tachypnea       Normal  Ambiguous
# 2                         5.112611  Normal (30-60)  Tachycardia  Ambiguous
# 3                         4.948540  Normal (30-60)       Normal  Ambiguous
# 4                         4.852990       Tachypnea  Tachycardia       Male
#
#    ... Premature Delivery Assistance needed in fertility  \
# 0  ...                Yes                             No
# 1  ...                  -                            Yes
# ...

# %%
# df['Breathing Rate'].unique()
# df.drop(df['Breathing Rate'] == np.NaN, axis = 0).isna().sum()

# %%
df.isna().sum()
# Out:
# Subject Id                                  0
# Subject Age                                 0
# Gene A                                      0
# Gene B                                    152
# Gene C                                   1390
# Gene D                                      0
# Per mcL quantity of blood cells             0
# Breathing Rate                           1040
# Pulse rate                               1036
# Gender                                   1030
# Gastrin Defect                           1047
# Neural Anomaly                           1025
# Presence of severe allergies             1060
# Premature Delivery                       1061
# Assistance needed in fertility           1041
# Previous maternal pregnancy record       1091
# Maternal Abortion count                  1037
# Per mcL quantity of white blood cells    1083
# CMP results                              1042
# A high triglyceride level                1062
# ...

# %%
df.dtypes
# Out:
# Subject Id                                object
# Subject Age                              float64
# Gene A                                    object
# Gene B                                    object
# Gene C                                    object
# Gene D                                    object
# Per mcL quantity of blood cells          float64
# Breathing Rate                            object
# Pulse rate                                object
# Gender                                    object
# Gastrin Defect                            object
# Neural Anomaly                            object
# Presence of severe allergies              object
# Premature Delivery                        object
# Assistance needed in fertility            object
# Previous maternal pregnancy record        object
# Maternal Abortion count                  float64
# Per mcL quantity of white blood cells    float64
# CMP results                               object
# ...

# %%
df[floatcol] = df[floatcol].fillna(df.mean().iloc[0])
X2[floatcol] = X2[floatcol].fillna(X2.mean().iloc[0])
df.isna().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_19688/3067267037.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[floatcol] = df[floatcol].fillna(df.mean().iloc[0])
# C:\Users\HP\AppData\Local\Temp/ipykernel_19688/3067267037.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   X2[floatcol] = X2[floatcol].fillna(X2.mean().iloc[0])
# Subject Id                                  0
# Subject Age                                 0
# Gene A                                      0
# Gene B                                    152
# Gene C                                   1390
# Gene D                                      0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df1 = df.fillna(df.mode().iloc[0]).iloc[:,:-1]
X2 = X2.fillna(X2.mode().iloc[0]).iloc[:,:]
df1['Metabolic Syndrome Type']=df['Metabolic Syndrome Type']
df1
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          6.0     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    Yes     No
# 12009  SID0x5af7          6.0    Yes     No    Yes     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# ...

# %%
df1.isna().sum()
# Out:
# Subject Id                               0
# Subject Age                              0
# Gene A                                   0
# Gene B                                   0
# Gene C                                   0
# Gene D                                   0
# Per mcL quantity of blood cells          0
# Breathing Rate                           0
# Pulse rate                               0
# Gender                                   0
# Gastrin Defect                           0
# Neural Anomaly                           0
# Presence of severe allergies             0
# Premature Delivery                       0
# Assistance needed in fertility           0
# Previous maternal pregnancy record       0
# Maternal Abortion count                  0
# Per mcL quantity of white blood cells    0
# CMP results                              0
# A high triglyceride level                0
# Reduced HDL                              0
# High BP                                  0
# ...

# %%
print(colms)
# Out:
# ['Subject Id', 'Gene A', 'Gene B', 'Gene C', 'Gene D', 'Breathing Rate', 'Pulse rate', 'Gender', 'Gastrin Defect', 'Neural Anomaly', 'Presence of severe allergies', 'Premature Delivery', 'Assistance needed in fertility', 'Previous maternal pregnancy record', 'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP']

# %%
df1.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP',
#        'Metabolic Syndrome Type'],
#       dtype='object')

# %%
X2.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP'],
#       dtype='object')

# %%
# df1.iloc[:,:-1] = df1.iloc[:,:-1].apply(LabelEncoder().fit_transform)
# df1
df1[colms] = df1[colms].apply(LabelEncoder().fit_transform)
X2[colms] = X2[colms].apply(LabelEncoder().fit_transform)
df1
# Out:
#        Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0            6123          1.0       0       0       0       0
# 1            8079          6.0       0       1       1       0
# 2            9677          7.0       0       0       0       1
# 3           10541          7.0       0       0       1       1
# 4            9308          5.0       1       0       1       1
# ...           ...          ...     ...     ...     ...     ...
# 12007        5491          0.0       1       0       1       0
# 12008        4360          1.0       1       0       1       0
# 12009        5545          6.0       1       0       1       0
# 12010        4880          1.0       1       1       0       0
# 12011        5160          9.0       1       0       0       1
#
#        Per mcL quantity of blood cells  Breathing Rate  Pulse rate  Gender  \
# 0                             4.717045               1           0       0
# ...

# %%
df1.isna().sum()
# Out:
# Subject Id                               0
# Subject Age                              0
# Gene A                                   0
# Gene B                                   0
# Gene C                                   0
# Gene D                                   0
# Per mcL quantity of blood cells          0
# Breathing Rate                           0
# Pulse rate                               0
# Gender                                   0
# Gastrin Defect                           0
# Neural Anomaly                           0
# Presence of severe allergies             0
# Premature Delivery                       0
# Assistance needed in fertility           0
# Previous maternal pregnancy record       0
# Maternal Abortion count                  0
# Per mcL quantity of white blood cells    0
# CMP results                              0
# A high triglyceride level                0
# Reduced HDL                              0
# High BP                                  0
# ...

# %%
X = df1.drop('Metabolic Syndrome Type', axis = 1)
y = df1['Metabolic Syndrome Type']
X.shape
# Out:
# (12012, 22)

# %%
X.to_csv('../data/X.csv')
y.to_csv('../data/y.csv')

# %%
X.head()
# Out:
#    Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0        6123          1.0       0       0       0       0
# 1        8079          6.0       0       1       1       0
# 2        9677          7.0       0       0       0       1
# 3       10541          7.0       0       0       1       1
# 4        9308          5.0       1       0       1       1
#
#    Per mcL quantity of blood cells  Breathing Rate  Pulse rate  Gender  ...  \
# 0                         4.717045               1           0       0  ...
# 1                         4.888077               1           0       0  ...
# 2                         5.112611               0           1       0  ...
# 3                         4.948540               0           0       0  ...
# 4                         4.852990               1           1       2  ...
#
#    Presence of severe allergies  Premature Delivery  \
# 0                             2                   3
# ...

# %%
X2.head()
# Out:
#    Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0        4327          7.0       1       1       0       1
# 1        3725          4.0       1       1       0       1
# 2        4087         14.0       0       0       0       0
# 3        2635         13.0       1       0       0       0
# 4        4080          4.0       1       0       0       0
#
#    Per mcL quantity of blood cells  Breathing Rate  Pulse rate  Gender  ...  \
# 0                         5.344305               1           1       1  ...
# 1                         4.948398               1           1       1  ...
# 2                         4.807918               1           0       2  ...
# 3                         4.887977               0           1       1  ...
# 4                         4.844576               0           1       1  ...
#
#    Presence of severe allergies  Premature Delivery  \
# 0                             1                   1
# ...

# %%
X2.to_csv('../data/X2.csv')

# %%
# from sklearn.model_selection import train_test_split
# Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=0)
# Xtrain.shape

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X, y)
# model.score(Xtest, ytest)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# print(Xtest.iloc[0])
# ytest.iloc[0]

# %%
# model.predict([Xtest.values[0]])

# %%
pred = model.predict(X2)
len(pred)
# Out:
# 5148

# %%
x2 = pd.read_csv('../data/test.csv')

# %%
dff = pd.DataFrame({'Subject Id':x2['Subject Id'],'Metabolic Syndrome Type':pred})
dff.head()
dff.shape
# Out:
# (5148, 2)

# %%
dff.to_csv('../submissionLR.csv', index = False)
