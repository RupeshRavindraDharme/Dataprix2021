# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/train.csv')
df
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          NaN     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    NaN     No
# 12009  SID0x5af7          NaN    Yes     No    NaN     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# 2                             5.112611  Normal (30-60)  Tachycardia
# 3                             4.948540  Normal (30-60)       Normal
# 4                             4.852990       Tachypnea  Tachycardia
# ...                                ...             ...          ...
# 12007                         4.617762  Normal (30-60)       Normal
# 12008                         4.602103       Tachypnea       Normal
# 12009                         5.114381       Tachypnea       Normal
# 12010                         4.988154  Normal (30-60)  Tachycardia
# 12011                         4.671745  Normal (30-60)       Normal
#
#        Diagnostic Testing  ...  Premature Delivery  \
# 0                     0.0  ...                 Yes
# 1                     NaN  ...                   -
# 2                     0.0  ...      Not applicable
# 3                     0.0  ...                  No
# 4                     0.0  ...                  No
# ...                   ...  ...                 ...
# 12007                 0.0  ...                 NaN
# 12008                 0.0  ...                  No
# 12009                 0.0  ...      Not applicable
# 12010                 0.0  ...                 NaN
# 12011                 NaN  ...                 Yes
#
#        Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                                  No                                 Yes
# 1                                 Yes                                 NaN
# 2                                 Yes                                 Yes
# 3                                 Yes                                 Yes
# 4                                 Yes                                  No
# ...                               ...                                 ...
# 12007                              No                                  No
# 12008                             Yes                                  No
# 12009                             Yes                                  No
# 12010                              No                                 Yes
# 12011                              No                                  No
#
#        Maternal Abortion count Per mcL quantity of white blood cells  \
# 0                          3.0                             11.857354
# 1                          NaN                              5.030793
# 2                          0.0                              7.248134
# 3                          4.0                             12.000000
# 4                          0.0                              6.422320
# ...                        ...                                   ...
# 12007                      3.0                              9.934496
# 12008                      2.0                             10.628694
# 12009                      3.0                              4.653705
# 12010                      4.0                              9.541917
# 12011                      0.0                              9.277975
#
#              CMP results A high triglyceride level Reduced HDL High BP  \
# 0               abnormal                       0.0         1.0     1.0
# 1      slightly abnormal                       NaN         0.0     1.0
# 2                 normal                       1.0         0.0     1.0
# 3               abnormal                       0.0         0.0     0.0
# 4                 normal                       1.0         1.0     0.0
# ...                  ...                       ...         ...     ...
# 12007  slightly abnormal                       NaN         0.0     0.0
# 12008  slightly abnormal                       1.0         0.0     0.0
# 12009  slightly abnormal                       1.0         0.0     0.0
# 12010                NaN                       0.0         1.0     0.0
# 12011       inconclusive                       1.0         0.0     1.0
#
#       Metabolic Syndrome Type
# 0                      Type C
# 1                      Type A
# 2                      Type A
# 3                      Type C
# 4                      Type B
# ...                       ...
# 12007                  Type A
# 12008                  Type C
# 12009                  Type C
# 12010                  Type C
# 12011                  Type A
#
# [12012 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Subject Id', 'Subject Age', 'Gene A', 'Gene B', 'Gene C', 'Gene D',
#        'Per mcL quantity of blood cells', 'Breathing Rate', 'Pulse rate',
#        'Diagnostic Testing', 'Carrier Testing', 'Enzyme Test', 'Insulin Test',
#        'Thyroid Test', 'Gender', 'Gastrin Defect', 'Neural Anomaly',
#        'Presence of severe allergies', 'Premature Delivery',
#        'Assistance needed in fertility', 'Previous maternal pregnancy record',
#        'Maternal Abortion count', 'Per mcL quantity of white blood cells',
#        'CMP results', 'A high triglyceride level', 'Reduced HDL', 'High BP',
#        'Metabolic Syndrome Type'],
#       dtype='object')

# %%
df.head()
# Out:
#   Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0  SID0x62bb          1.0     No     No     No     No
# 1   SID0x78c          NaN     No    Yes    Yes     No
# 2  SID0x88f4          7.0     No     No     No    Yes
# 3  SID0x919e          7.0     No     No    Yes    Yes
# 4  SID0x8534          5.0    Yes     No    Yes    Yes
#
#    Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                         4.717045       Tachypnea       Normal
# 1                         4.888077       Tachypnea       Normal
# 2                         5.112611  Normal (30-60)  Tachycardia
# 3                         4.948540  Normal (30-60)       Normal
# 4                         4.852990       Tachypnea  Tachycardia
#
#    Diagnostic Testing  ...  Premature Delivery  \
# 0                 0.0  ...                 Yes
# 1                 NaN  ...                   -
# 2                 0.0  ...      Not applicable
# 3                 0.0  ...                  No
# 4                 0.0  ...                  No
#
#    Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                              No                                 Yes
# 1                             Yes                                 NaN
# 2                             Yes                                 Yes
# 3                             Yes                                 Yes
# 4                             Yes                                  No
#
#    Maternal Abortion count Per mcL quantity of white blood cells  \
# 0                      3.0                             11.857354
# 1                      NaN                              5.030793
# 2                      0.0                              7.248134
# 3                      4.0                             12.000000
# 4                      0.0                              6.422320
#
#          CMP results A high triglyceride level Reduced HDL High BP  \
# 0           abnormal                       0.0         1.0     1.0
# 1  slightly abnormal                       NaN         0.0     1.0
# 2             normal                       1.0         0.0     1.0
# 3           abnormal                       0.0         0.0     0.0
# 4             normal                       1.0         1.0     0.0
#
#   Metabolic Syndrome Type
# 0                  Type C
# 1                  Type A
# 2                  Type A
# 3                  Type C
# 4                  Type B
#
# [5 rows x 28 columns]

# %%
df.isna().sum()
# Out:
# Subject Id                                  0
# Subject Age                               729
# Gene A                                      0
# Gene B                                    152
# Gene C                                   1390
# Gene D                                      0
# Per mcL quantity of blood cells             0
# Breathing Rate                           1040
# Pulse rate                               1036
# Diagnostic Testing                       1066
# Carrier Testing                          1065
# Enzyme Test                              1040
# Insulin Test                             1052
# Thyroid Test                             1044
# Gender                                   1030
# Gastrin Defect                           1047
# Neural Anomaly                           1025
# Presence of severe allergies             1060
# Premature Delivery                       1061
# Assistance needed in fertility           1041
# Previous maternal pregnancy record       1091
# Maternal Abortion count                  1037
# Per mcL quantity of white blood cells    1083
# CMP results                              1042
# A high triglyceride level                1062
# Reduced HDL                              1042
# High BP                                  1066
# Metabolic Syndrome Type                     0
# dtype: int64

# %%
df
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          NaN     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    NaN     No
# 12009  SID0x5af7          NaN    Yes     No    NaN     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# 2                             5.112611  Normal (30-60)  Tachycardia
# 3                             4.948540  Normal (30-60)       Normal
# 4                             4.852990       Tachypnea  Tachycardia
# ...                                ...             ...          ...
# 12007                         4.617762  Normal (30-60)       Normal
# 12008                         4.602103       Tachypnea       Normal
# 12009                         5.114381       Tachypnea       Normal
# 12010                         4.988154  Normal (30-60)  Tachycardia
# 12011                         4.671745  Normal (30-60)       Normal
#
#        Diagnostic Testing  ...  Premature Delivery  \
# 0                     0.0  ...                 Yes
# 1                     NaN  ...                   -
# 2                     0.0  ...      Not applicable
# 3                     0.0  ...                  No
# 4                     0.0  ...                  No
# ...                   ...  ...                 ...
# 12007                 0.0  ...                 NaN
# 12008                 0.0  ...                  No
# 12009                 0.0  ...      Not applicable
# 12010                 0.0  ...                 NaN
# 12011                 NaN  ...                 Yes
#
#        Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                                  No                                 Yes
# 1                                 Yes                                 NaN
# 2                                 Yes                                 Yes
# 3                                 Yes                                 Yes
# 4                                 Yes                                  No
# ...                               ...                                 ...
# 12007                              No                                  No
# 12008                             Yes                                  No
# 12009                             Yes                                  No
# 12010                              No                                 Yes
# 12011                              No                                  No
#
#        Maternal Abortion count Per mcL quantity of white blood cells  \
# 0                          3.0                             11.857354
# 1                          NaN                              5.030793
# 2                          0.0                              7.248134
# 3                          4.0                             12.000000
# 4                          0.0                              6.422320
# ...                        ...                                   ...
# 12007                      3.0                              9.934496
# 12008                      2.0                             10.628694
# 12009                      3.0                              4.653705
# 12010                      4.0                              9.541917
# 12011                      0.0                              9.277975
#
#              CMP results A high triglyceride level Reduced HDL High BP  \
# 0               abnormal                       0.0         1.0     1.0
# 1      slightly abnormal                       NaN         0.0     1.0
# 2                 normal                       1.0         0.0     1.0
# 3               abnormal                       0.0         0.0     0.0
# 4                 normal                       1.0         1.0     0.0
# ...                  ...                       ...         ...     ...
# 12007  slightly abnormal                       NaN         0.0     0.0
# 12008  slightly abnormal                       1.0         0.0     0.0
# 12009  slightly abnormal                       1.0         0.0     0.0
# 12010                NaN                       0.0         1.0     0.0
# 12011       inconclusive                       1.0         0.0     1.0
#
#       Metabolic Syndrome Type
# 0                      Type C
# 1                      Type A
# 2                      Type A
# 3                      Type C
# 4                      Type B
# ...                       ...
# 12007                  Type A
# 12008                  Type C
# 12009                  Type C
# 12010                  Type C
# 12011                  Type A
#
# [12012 rows x 28 columns]

# %%
from sklearn.preprocessing import LabelEncoder
df1 = df.fillna(df.mode().iloc[0]).iloc[:,:-1]
df1['Metabolic Syndrome Type']=df['Metabolic Syndrome Type']
df1
# Out:
#       Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0      SID0x62bb          1.0     No     No     No     No
# 1       SID0x78c          0.0     No    Yes    Yes     No
# 2      SID0x88f4          7.0     No     No     No    Yes
# 3      SID0x919e          7.0     No     No    Yes    Yes
# 4      SID0x8534          5.0    Yes     No    Yes    Yes
# ...          ...          ...    ...    ...    ...    ...
# 12007  SID0x5a3c          0.0    Yes     No    Yes     No
# 12008  SID0x4bd2          1.0    Yes     No    Yes     No
# 12009  SID0x5af7          0.0    Yes     No    Yes     No
# 12010  SID0x52d1          1.0    Yes    Yes     No     No
# 12011  SID0x5642          9.0    Yes     No     No    Yes
#
#        Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                             4.717045       Tachypnea       Normal
# 1                             4.888077       Tachypnea       Normal
# 2                             5.112611  Normal (30-60)  Tachycardia
# 3                             4.948540  Normal (30-60)       Normal
# 4                             4.852990       Tachypnea  Tachycardia
# ...                                ...             ...          ...
# 12007                         4.617762  Normal (30-60)       Normal
# 12008                         4.602103       Tachypnea       Normal
# 12009                         5.114381       Tachypnea       Normal
# 12010                         4.988154  Normal (30-60)  Tachycardia
# 12011                         4.671745  Normal (30-60)       Normal
#
#        Diagnostic Testing  ...  Premature Delivery  \
# 0                     0.0  ...                 Yes
# 1                     0.0  ...                   -
# 2                     0.0  ...      Not applicable
# 3                     0.0  ...                  No
# 4                     0.0  ...                  No
# ...                   ...  ...                 ...
# 12007                 0.0  ...                  No
# 12008                 0.0  ...                  No
# 12009                 0.0  ...      Not applicable
# 12010                 0.0  ...                  No
# 12011                 0.0  ...                 Yes
#
#        Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                                  No                                 Yes
# 1                                 Yes                                 Yes
# 2                                 Yes                                 Yes
# 3                                 Yes                                 Yes
# 4                                 Yes                                  No
# ...                               ...                                 ...
# 12007                              No                                  No
# 12008                             Yes                                  No
# 12009                             Yes                                  No
# 12010                              No                                 Yes
# 12011                              No                                  No
#
#        Maternal Abortion count Per mcL quantity of white blood cells  \
# 0                          3.0                             11.857354
# 1                          2.0                              5.030793
# 2                          0.0                              7.248134
# 3                          4.0                             12.000000
# 4                          0.0                              6.422320
# ...                        ...                                   ...
# 12007                      3.0                              9.934496
# 12008                      2.0                             10.628694
# 12009                      3.0                              4.653705
# 12010                      4.0                              9.541917
# 12011                      0.0                              9.277975
#
#              CMP results A high triglyceride level Reduced HDL High BP  \
# 0               abnormal                       0.0         1.0     1.0
# 1      slightly abnormal                       1.0         0.0     1.0
# 2                 normal                       1.0         0.0     1.0
# 3               abnormal                       0.0         0.0     0.0
# 4                 normal                       1.0         1.0     0.0
# ...                  ...                       ...         ...     ...
# 12007  slightly abnormal                       1.0         0.0     0.0
# 12008  slightly abnormal                       1.0         0.0     0.0
# 12009  slightly abnormal                       1.0         0.0     0.0
# 12010  slightly abnormal                       0.0         1.0     0.0
# 12011       inconclusive                       1.0         0.0     1.0
#
#       Metabolic Syndrome Type
# 0                      Type C
# 1                      Type A
# 2                      Type A
# 3                      Type C
# 4                      Type B
# ...                       ...
# 12007                  Type A
# 12008                  Type C
# 12009                  Type C
# 12010                  Type C
# 12011                  Type A
#
# [12012 rows x 28 columns]

# %%
df1.iloc[:,:-1] = df1.iloc[:,:-1].apply(LabelEncoder().fit_transform)
df1
# Out:
#        Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0            6123            1       0       0       0       0
# 1            8079            0       0       1       1       0
# 2            9677            7       0       0       0       1
# 3           10541            7       0       0       1       1
# 4            9308            5       1       0       1       1
# ...           ...          ...     ...     ...     ...     ...
# 12007        5491            0       1       0       1       0
# 12008        4360            1       1       0       1       0
# 12009        5545            0       1       0       1       0
# 12010        4880            1       1       1       0       0
# 12011        5160            9       1       0       0       1
#
#        Per mcL quantity of blood cells  Breathing Rate  Pulse rate  \
# 0                                 2140               1           0
# 1                                 5671               1           0
# 2                                10253               0           1
# 3                                 7106               0           0
# 4                                 4869               1           1
# ...                                ...             ...         ...
# 12007                              959               0           0
# 12008                              825               1           0
# 12009                            10280               1           0
# 12010                             7991               0           1
# 12011                             1519               0           0
#
#        Diagnostic Testing  ...  Premature Delivery  \
# 0                       0  ...                   3
# 1                       0  ...                   0
# 2                       0  ...                   2
# 3                       0  ...                   1
# 4                       0  ...                   1
# ...                   ...  ...                 ...
# 12007                   0  ...                   1
# 12008                   0  ...                   1
# 12009                   0  ...                   2
# 12010                   0  ...                   1
# 12011                   0  ...                   3
#
#        Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                                   0                                   1
# 1                                   1                                   1
# 2                                   1                                   1
# 3                                   1                                   1
# 4                                   1                                   0
# ...                               ...                                 ...
# 12007                               0                                   0
# 12008                               1                                   0
# 12009                               1                                   0
# 12010                               0                                   1
# 12011                               0                                   0
#
#        Maternal Abortion count  Per mcL quantity of white blood cells  \
# 0                            3                                   9412
# 1                            2                                   1552
# 2                            0                                   4467
# 3                            4                                   9486
# 4                            0                                   3265
# ...                        ...                                    ...
# 12007                        3                                   7967
# 12008                        2                                   8618
# 12009                        3                                   1178
# 12010                        4                                   7510
# 12011                        0                                   7203
#
#        CMP results  A high triglyceride level  Reduced HDL  High BP  \
# 0                0                          0            1        1
# 1                3                          1            0        1
# 2                2                          1            0        1
# 3                0                          0            0        0
# 4                2                          1            1        0
# ...            ...                        ...          ...      ...
# 12007            3                          1            0        0
# 12008            3                          1            0        0
# 12009            3                          1            0        0
# 12010            3                          0            1        0
# 12011            1                          1            0        1
#
#        Metabolic Syndrome Type
# 0                       Type C
# 1                       Type A
# 2                       Type A
# 3                       Type C
# 4                       Type B
# ...                        ...
# 12007                   Type A
# 12008                   Type C
# 12009                   Type C
# 12010                   Type C
# 12011                   Type A
#
# [12012 rows x 28 columns]

# %%
import seaborn as sns
corr = df1.corr()
sns.heatmap(corr, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df1.head()
# Out:
#    Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0        6123            1       0       0       0       0
# 1        8079            0       0       1       1       0
# 2        9677            7       0       0       0       1
# 3       10541            7       0       0       1       1
# 4        9308            5       1       0       1       1
#
#    Per mcL quantity of blood cells  Breathing Rate  Pulse rate  \
# 0                             2140               1           0
# 1                             5671               1           0
# 2                            10253               0           1
# 3                             7106               0           0
# 4                             4869               1           1
#
#    Diagnostic Testing  ...  Premature Delivery  \
# 0                   0  ...                   3
# 1                   0  ...                   0
# 2                   0  ...                   2
# 3                   0  ...                   1
# 4                   0  ...                   1
#
#    Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                               0                                   1
# 1                               1                                   1
# 2                               1                                   1
# 3                               1                                   1
# 4                               1                                   0
#
#    Maternal Abortion count  Per mcL quantity of white blood cells  \
# 0                        3                                   9412
# 1                        2                                   1552
# 2                        0                                   4467
# 3                        4                                   9486
# 4                        0                                   3265
#
#    CMP results  A high triglyceride level  Reduced HDL  High BP  \
# 0            0                          0            1        1
# 1            3                          1            0        1
# 2            2                          1            0        1
# 3            0                          0            0        0
# 4            2                          1            1        0
#
#    Metabolic Syndrome Type
# 0                   Type C
# 1                   Type A
# 2                   Type A
# 3                   Type C
# 4                   Type B
#
# [5 rows x 28 columns]

# %%
X = df1.drop('Metabolic Syndrome Type', axis = 1)
y = df1['Metabolic Syndrome Type']
X.shape
# Out:
# (12012, 27)

# %%
# from sklearn.model_selection import train_test_split
# Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=0)
# Xtrain.shape

# %%
from sklearn.linear_model import LogisticRegressionCV 
model = LogisticRegressionCV(max_iter=1000)
model.fit(X, y)
# model.score(Xtest, ytest)
# Out:
# LogisticRegressionCV(max_iter=1000)

# %%
# print(Xtest.iloc[0])
# ytest.iloc[0]

# %%
# model.predict([Xtest.values[0]])

# %%
test = pd.read_csv('../data/test.csv')
test.head()
# Out:
#   Subject Id  Subject Age Gene A Gene B Gene C Gene D  \
# 0   SID0x8cc          7.0    Yes    Yes     No    Yes
# 1  SID0x7f0b          4.0    Yes    Yes     No    Yes
# 2  SID0x8778         14.0     No     No     No     No
# 3  SID0x6296         13.0    Yes     No     No     No
# 4  SID0x874f          4.0    Yes     No     No     No
#
#    Per mcL quantity of blood cells  Breathing Rate   Pulse rate  \
# 0                         5.344305             NaN  Tachycardia
# 1                         4.948398       Tachypnea  Tachycardia
# 2                         4.807918       Tachypnea       Normal
# 3                         4.887977  Normal (30-60)  Tachycardia
# 4                         4.844576  Normal (30-60)  Tachycardia
#
#    Diagnostic Testing  ...  Presence of severe allergies  Premature Delivery  \
# 0                 0.0  ...                            No                 NaN
# 1                 0.0  ...                           Yes                 Yes
# 2                 0.0  ...                Not applicable                 Yes
# 3                 0.0  ...                            No                 NaN
# 4                 0.0  ...                            No                  No
#
#    Assistance needed in fertility  Previous maternal pregnancy record  \
# 0                              No                                 Yes
# 1                             Yes                                  No
# 2                              No                                  No
# 3                              No                                 NaN
# 4                              No                                 Yes
#
#   Maternal Abortion count Per mcL quantity of white blood cells  \
# 0                     4.0                             12.000000
# 1                     2.0                              5.155980
# 2                     3.0                              6.422633
# 3                     2.0                              9.620953
# 4                     4.0                             10.180693
#
#          CMP results A high triglyceride level Reduced HDL High BP
# 0           abnormal                       0.0         1.0     1.0
# 1       inconclusive                       1.0         1.0     1.0
# 2  slightly abnormal                       1.0         0.0     0.0
# 3             normal                       1.0         0.0     1.0
# 4       inconclusive                       0.0         0.0     0.0
#
# [5 rows x 27 columns]

# %%
X2 = test.apply(LabelEncoder().fit_transform)
X2
# Out:
#       Subject Id  Subject Age  Gene A  Gene B  Gene C  Gene D  \
# 0           4327            7       1       1       0       1
# 1           3725            4       1       1       0       1
# 2           4087           14       0       0       0       0
# 3           2635           13       1       0       0       0
# 4           4080            4       1       0       0       0
# ...          ...          ...     ...     ...     ...     ...
# 5143        2990           14       1       1       1       0
# 5144        5084            8       1       0       0       1
# 5145        2985            5       0       0       1       1
# 5146         202            8       1       0       0       0
# 5147        4270            8       0       1       0       1
#
#       Per mcL quantity of blood cells  Breathing Rate  Pulse rate  \
# 0                                5089               2           1
# 1                                3131               1           1
# 2                                1674               1           0
# 3                                2491               0           1
# 4                                2054               0           1
# ...                               ...             ...         ...
# 5143                             3386               0           0
# 5144                             4160               0           1
# 5145                             4559               0           0
# 5146                              413               1           0
# 5147                             3327               1           1
#
#       Diagnostic Testing  ...  Presence of severe allergies  \
# 0                      0  ...                             1
# 1                      0  ...                             3
# 2                      0  ...                             2
# 3                      0  ...                             1
# 4                      0  ...                             1
# ...                  ...  ...                           ...
# 5143                   0  ...                             0
# 5144                   0  ...                             0
# 5145                   0  ...                             0
# 5146                   1  ...                             2
# 5147                   0  ...                             3
#
#       Premature Delivery  Assistance needed in fertility  \
# 0                      4                               0
# 1                      3                               1
# 2                      3                               0
# 3                      4                               0
# 4                      1                               0
# ...                  ...                             ...
# 5143                   3                               0
# 5144                   3                               1
# 5145                   1                               1
# 5146                   2                               2
# 5147                   0                               0
#
#       Previous maternal pregnancy record  Maternal Abortion count  \
# 0                                      1                        4
# 1                                      0                        2
# 2                                      0                        3
# 3                                      2                        2
# 4                                      1                        4
# ...                                  ...                      ...
# 5143                                   0                        2
# 5144                                   0                        3
# 5145                                   0                        1
# 5146                                   2                        3
# 5147                                   1                        3
#
#       Per mcL quantity of white blood cells  CMP results  \
# 0                                      4055            0
# 1                                       715            1
# 2                                      1360            3
# 3                                      3228            2
# 4                                      3478            1
# ...                                     ...          ...
# 5143                                      0            3
# 5144                                   4056            2
# 5145                                   4048            2
# 5146                                    121            0
# 5147                                   2712            1
#
#       A high triglyceride level  Reduced HDL  High BP
# 0                             0            1        1
# 1                             1            1        1
# 2                             1            0        0
# 3                             1            0        1
# 4                             0            0        0
# ...                         ...          ...      ...
# 5143                          0            0        1
# 5144                          1            1        1
# 5145                          0            0        1
# 5146                          2            1        1
# 5147                          1            1        0
#
# [5148 rows x 27 columns]

# %%
pred = model.predict(X2)
len(pred)
model.score(X, y)
# Out:
# 0.5108225108225108

# %%
dff = df = pd.DataFrame({'Subject Id':test['Subject Id'],'Metabolic Syndrome Type':pred})
dff.head()
dff.shape
# Out:
# (5148, 2)

# %%
dff.to_csv('../submissionLRCV.csv', index = False)
